# %% [markdown]
# ### Homework 5
# ##### Name: Thu Trang
# ##### Student ID: 11230595
# ##### Class: DSEB65A

# %% [markdown]
# **Ex1**

# %%
import nltk
import string
message = """Machine learning; (ML) is the study of \ computer algorithms that improve automatically through# experience. It is seen as a subset of artificial intelligence. Machine learning algorithms build a mathematical model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so. Machine{ learning} algorithms are used in a wide variety of applications, such as email filtering and computer() vision, where it is difficult or infeasible to develop conventional algorithms to perform the needed tasks. Machine# learning is closely related to computational *statistics, which focuses on making predictions! using computers. The study of mathematical optimization delivers methods, theory and application domains to the-- field ;of machine learning. Data mining is a related field of study, focusing on exploratory data analysis through unsupervised learning In its application across business problems, machine learning is also referred to as predictive analytics."""
remove_punctuations = str.maketrans('!;#*--{()}\\', '           ')
message = message.translate(remove_punctuations)
count = 0
sentences = nltk.sent_tokenize(message)
print(f"There are {len(sentences)} sentences")
for sentence in sentences:
    sentence = sentence.translate(str.maketrans('', '', string.punctuation))
    words = nltk.word_tokenize(sentence)
    print(len(words))
# Out:
# There are 7 sentences
# 14
# 9
# 29
# 33
# 15
# 17
# 31
# <>:3: SyntaxWarning: invalid escape sequence '\ '
# <>:3: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/bg/hsvxykxj7yx0jz1nrhc3k6z40000gn/T/ipykernel_30956/2518259594.py:3: SyntaxWarning: invalid escape sequence '\ '
# ...

# %%
from collections import Counter
import string
import nltk

dseb_words = {'data', 'machine', 'learning', 'mining', 'analysis', 'unsupervised', 'business', 'optimization', 'model'}
overall_fre_words = Counter()
for sentence in sentences:
    sentence = sentence.translate(str.maketrans('', '', string.punctuation))
    words = nltk.word_tokenize(sentence)
    fre_words = [word.lower() for word in words if word.lower() in dseb_words]
    overall_fre_words.update(fre_words)
freq_dict = dict(overall_fre_words)
print(freq_dict)
# Out:
# {'machine': 6, 'learning': 7, 'model': 1, 'data': 4, 'optimization': 1, 'mining': 1, 'analysis': 1, 'unsupervised': 1, 'business': 1}

# %%
begin_count = 0
end_count = 0
for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    for word in words[:len(words)//2]:
        if word.lower() in dseb_words:
            begin_count += 1
    for word in words[len(words)//2:]:
        if word.lower() in dseb_words:
            end_count += 1
print(begin_count)
print(end_count)
if begin_count > end_count:
    print("More sentences start with a DSEB word")
else:
    print("More sentences end with a DSEB word")
# Out:
# 18
# 5
# More sentences start with a DSEB word

# %% [markdown]
# **Ex2**

# %%
n = int(input("Enter integer n:"))
def prime(x):
    if x == 1:
        return False
    for i in range(2, x):
        if x % i == 0:
            return False
    return True
i = 0
x = 2
while i < n:
    if prime(x):
        i += 1
    x += 1

print(x - 1)
# Out:
# 11

# %% [markdown]
# **Ex3**

# %%
a = int(input("Enter integer a:"))
b = int(input("Enter integer b:"))

i = 1
while i <= a and i <= b:
    if a % i == 0 and b % i == 0:
        gcd = i
    i += 1
print("GCD of", a, "and", b, "is", gcd)
# Out:
# GCD of 4 and 6 is 2

# %%
a = int(input("Enter integer a:"))
b = int(input("Enter integer b:"))

def gcd(x, y):
    if x == 0:
        return y
    return gcd(y % x, x)

print("GCD of", a, "and", b, "is", gcd(a, b))
# Out:
# GCD of 4 and 6 is 2

# %% [markdown]
# **Ex4**

# %%
a = int(input("Enter integer a:"))
b = int(input("Enter integer b:"))

if a > b:
    lcm = a
else:
    lcm = b
while(True):
    if lcm % a == 0 and lcm % b == 0:
        print("LCM of", a, "and", b, "is", lcm)
        break
    lcm += 1
# Out:
# LCM of 4 and 6 is 12

# %%
a = int(input("Enter integer a:"))
b = int(input("Enter integer b:"))

def lcm(x, y):
    return x * y // gcd(x, y)

print("LCM of", a, "and", b, "is", lcm(a, b))
# Out:
# LCM of 4 and 6 is 12

# %% [markdown]
# **Ex5**

# %%
n = int(input("Enter integer n:"))
count = 0
sum = 0
temp = n
while temp > 0:
    temp = temp // 10
    count += 1

temp1 = n
while temp1 > 0:
    x = temp1 % 10
    sum += x**count
    temp1 = temp1 // 10
if sum == n:
    print("Armstrong number")
else:
    print("Not Armstrong number")
# Out:
# Armstrong number
